# %% [markdown]
# Ejercicio 10 de la practica 2

# %%
import sys
sys.path.append("../src")
from ejercicio10 import procesar_competencia
from datos_ejercicio10 import rounds

# %%
procesar_competencia(rounds)
